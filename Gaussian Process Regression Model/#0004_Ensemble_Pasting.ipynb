# %% [markdown]
# # Ensemble Learning through Pasting
#
# **Pasting == Bootstrapping Aggregation W/O replacement**
#
# $\implies$  hyperparam = {M = #learners, alpha = # relative trainset size}

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel

# add project root folder to path to allow import local modules
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
# import local modules
from stochastic_models import *
from visualisations import *
from basic_estimator_model import *

# %% [markdown]
# ## Parameter Configuration

# %%
np.random.seed(2020)

# %%
N_train = 5000
N_test = 50000
d = 1
T = 2

# %%
lambda_range = (N_train*1e-9 , N_train*1e-3)
alpha_range = (8.3*1e-5, 0.83)
length_scale = np.sort(1/np.sqrt((2*alpha_range[0], 2*alpha_range[1])))

# %% [markdown]
# ## Create Kernel & prepare datasets

# %%
#kernel
kernel = RBF(length_scale= (length_scale[0] + length_scale[1])/2, length_scale_bounds=length_scale) \
        + WhiteKernel(noise_level= (lambda_range[0] + lambda_range[1])/2 , noise_level_bounds=lambda_range)

# %%
#generate drivers
s_train = MaxCallStochasticModel(N_train,d,[1/12,11/12])
s_train.generate_samples()
s_test = MaxCallStochasticModel(N_test, d, [1/12,11/12])
s_test.generate_samples()

# %%
#prepare datasets & values
y_train = s_train.y
X_train = s_train.X
S_train = s_train.S

y_test = s_test.y
X_test = s_test.X
S_test = s_test.S

V_T = y_test  
V_0 = s_test.generate_true_V(0)

V_0= V_0.mean()
V_0 # Average expected PROFIT!
# Out:
# 0.0793534441124991

# %%
X_test.shape
# Out:
# (50000, 1, 2)

# %% [markdown]
# ## Create Custom Models
# (to have more control of splitting etc)

# %%
from aggregating.models import SimpleBagger
s = SimplePaster(11,0.5,None)
s.get_params()
# Out:
# {'M': 11, 'predictor': None, 'train_size_alpha': 0.5}

# %% [markdown]
# ## GridSearch
#
# nB: cannot use Scikit gridsearch as it performs CV and we want to have a different test set of a larger size!

# %%
from multiprocessing import  cpu_count,current_process
from multiprocessing.pool import ThreadPool
import functools
import threading

from aggregating.gridsearch import create_logger, evaluate_model
from aggregating.utils import flatten_X

# GRIDSEARCH PARAMS
model = SimpleBagger(0,0,GaussianProcessRegressor(kernel,copy_X_train=False))
trials = 3
M_grid = [1,2,3,4,5,6,7,8]
alpha_grid = [0.5,0.7,0.9,1.0]
results = []

### ACTUAL GRIDSEARCH
pool = ThreadPool(4) #avoid allocation issues
for m in M_grid:
    for alpha in alpha_grid:
        hyperparams= {'M':m, 'train_size_alpha':alpha}
        pool.apply_async(evaluate_model, args=(model,hyperparams,flatten_X(X_train),y_train,1, [1/12,11/12],trials,N_test,MaxCallStochasticModel),callback = create_logger(hyperparams,results))
pool.close()
pool.join()
# Out:
#  {'M': 1, 'train_size_alpha': 0.5} -> thread id = 30312
# fit
# (5000, 2)
#  {'M': 1, 'train_size_alpha': 0.7} -> thread id = 19248
# fit
# (5000, 2)
#  {'M': 1, 'train_size_alpha': 0.9} -> thread id = 2532
# fit
# (5000, 2)
#  {'M': 1, 'train_size_alpha': 1.0} -> thread id = 4336
# fit
# (5000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.5} , 0 -> 0.24638305622193926
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.9} , 0 -> 0.22620107782688725
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.5} , 1 -> 0.19748239864428063
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 1.0} , 0 -> 0.25083322357295385
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.7} , 0 -> 0.21515010491763945
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.5} , 2 -> 0.2083075643798671
# {'M': 1, 'train_size_alpha': 0.5} -> [0.24638305622193926, 0.19748239864428063, 0.2083075643798671]
#  {'M': 2, 'train_size_alpha': 0.5} -> thread id = 30312logger {'M': 1, 'train_size_alpha': 0.5}, -> [0.24638305622193926, 0.19748239864428063, 0.2083075643798671]
#
# fit
# (5000, 2)
# {'M': 1, 'train_size_alpha': 0.9} , 1 -> 0.20179432463046795
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.7} , 1 -> 0.21090538157442631
# {'M': 1, 'train_size_alpha': 1.0} , 1 -> 0.347046760187427
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.9} , 2 -> 0.21248447643245472
# {'M': 1, 'train_size_alpha': 0.9} -> [0.22620107782688725, 0.20179432463046795, 0.21248447643245472]
#  {'M': 2, 'train_size_alpha': 0.7} -> thread id = 2532
# fit
# (5000, 2)
# logger {'M': 1, 'train_size_alpha': 0.9}, -> [0.22620107782688725, 0.20179432463046795, 0.21248447643245472]
# {'M': 1, 'train_size_alpha': 0.7} , 2 -> 0.2268291505486027
# {'M': 1, 'train_size_alpha': 0.7} -> [0.21515010491763945, 0.21090538157442631, 0.2268291505486027]
#  {'M': 2, 'train_size_alpha': 0.9} -> thread id = 19248
# fit
# (5000, 2)
# logger {'M': 1, 'train_size_alpha': 0.7}, -> [0.21515010491763945, 0.21090538157442631, 0.2268291505486027]
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 1.0} , 2 -> 0.23988363388875894
# {'M': 1, 'train_size_alpha': 1.0} -> [0.25083322357295385, 0.347046760187427, 0.23988363388875894]
#  {'M': 2, 'train_size_alpha': 1.0} -> thread id = 4336logger {'M': 1, 'train_size_alpha': 1.0}, -> [0.25083322357295385, 0.347046760187427, 0.23988363388875894]
#
# fit
# (5000, 2)
# {'M': 2, 'train_size_alpha': 0.5} , 0 -> 0.18427087910989617
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.5} , 1 -> 0.21283031004818878
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.5} , 2 -> 0.20917872228407577
# {'M': 2, 'train_size_alpha': 0.5} -> [0.18427087910989617, 0.21283031004818878, 0.20917872228407577]
#  {'M': 3, 'train_size_alpha': 0.5} -> thread id = 30312logger {'M': 2, 'train_size_alpha': 0.5}, -> [0.18427087910989617, 0.21283031004818878, 0.20917872228407577]
#
# fit
# (5000, 2)
# {'M': 2, 'train_size_alpha': 0.7} , 0 -> 0.17186745683969423
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.9} , 0 -> 0.15353303074336644
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 1.0} , 0 -> 0.18353369916750845
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.7} , 1 -> 0.21085307180208787
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.9} , 1 -> 0.19789926820465958
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.7} , 2 -> 0.17949720182782014
# {'M': 2, 'train_size_alpha': 0.7} -> [0.17186745683969423, 0.21085307180208787, 0.17949720182782014]
#  {'M': 3, 'train_size_alpha': 0.7} -> thread id = 2532logger {'M': 2, 'train_size_alpha': 0.7}, -> [0.17186745683969423, 0.21085307180208787, 0.17949720182782014]
#
# fit
# (5000, 2)
# {'M': 3, 'train_size_alpha': 0.5} , 0 -> 0.14856195679521506
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 1.0} , 1 -> 0.18709670092754127
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.9} , 2 -> 0.18176155632909866
# {'M': 2, 'train_size_alpha': 0.9} -> [0.15353303074336644, 0.19789926820465958, 0.18176155632909866]
#  {'M': 3, 'train_size_alpha': 0.9} -> thread id = 19248logger {'M': 2, 'train_size_alpha': 0.9}, -> [0.15353303074336644, 0.19789926820465958, 0.18176155632909866]
#
# fit
# (5000, 2)
# {'M': 3, 'train_size_alpha': 0.5} , 1 -> 0.18546436743973704
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 1.0} , 2 -> 0.2393356418209169
# {'M': 2, 'train_size_alpha': 1.0} -> [0.18353369916750845, 0.18709670092754127, 0.2393356418209169]
#  {'M': 3, 'train_size_alpha': 1.0} -> thread id = 4336logger {'M': 2, 'train_size_alpha': 1.0}, -> [0.18353369916750845, 0.18709670092754127, 0.2393356418209169]
#
# fit
# (5000, 2)
# {'M': 3, 'train_size_alpha': 0.5} , 2 -> 0.12439398433546782
# {'M': 3, 'train_size_alpha': 0.5} -> [0.14856195679521506, 0.18546436743973704, 0.12439398433546782]
#  {'M': 4, 'train_size_alpha': 0.5} -> thread id = 30312
# logger {'M': 3, 'train_size_alpha': 0.5}, -> [0.14856195679521506, 0.18546436743973704, 0.12439398433546782]fit
# (5000, 2)
#
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.7} , 0 -> 0.22452513957395098
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.9} , 0 -> 0.2422442589902948
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.5} , 0 -> 0.23050746892210158
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.7} , 1 -> 0.20314044678109186
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 1.0} , 0 -> 0.21482865604332374
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.5} , 1 -> 0.2023083708473144
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.7} , 2 -> 0.2307966693692901
# {'M': 3, 'train_size_alpha': 0.7} -> [0.22452513957395098, 0.20314044678109186, 0.2307966693692901]
#  {'M': 4, 'train_size_alpha': 0.7} -> thread id = 2532logger {'M': 3, 'train_size_alpha': 0.7}, -> [0.22452513957395098, 0.20314044678109186, 0.2307966693692901]
#
# fit
# (5000, 2)
# {'M': 3, 'train_size_alpha': 0.9} , 1 -> 0.17465926228506146
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.5} , 2 -> 0.2752425980881491
# {'M': 4, 'train_size_alpha': 0.5} -> [0.23050746892210158, 0.2023083708473144, 0.2752425980881491]
#  {'M': 4, 'train_size_alpha': 0.9} -> thread id = 30312{'M': 3, 'train_size_alpha': 1.0} , 1 -> 0.20325138865325473
#
# logger {'M': 4, 'train_size_alpha': 0.5}, -> [0.23050746892210158, 0.2023083708473144, 0.2752425980881491]
# fit
# (5000, 2)
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.9} , 2 -> 0.2109264607519316
# {'M': 3, 'train_size_alpha': 0.9} -> [0.2422442589902948, 0.17465926228506146, 0.2109264607519316]
#  {'M': 4, 'train_size_alpha': 1.0} -> thread id = 19248
# logger {'M': 3, 'train_size_alpha': 0.9}, -> [0.2422442589902948, 0.17465926228506146, 0.2109264607519316]fit
#
# (5000, 2)
# {'M': 3, 'train_size_alpha': 1.0} , 2 -> 0.15116029062327122
# {'M': 3, 'train_size_alpha': 1.0} -> [0.21482865604332374, 0.20325138865325473, 0.15116029062327122]
#  {'M': 5, 'train_size_alpha': 0.5} -> thread id = 4336logger {'M': 3, 'train_size_alpha': 1.0}, -> [0.21482865604332374, 0.20325138865325473, 0.15116029062327122]
#
# fit
# (5000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.7} , 0 -> 0.23720676389631998
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.9} , 0 -> 0.21078455979161972
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.5} , 0 -> 0.2061209336429454
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.7} , 1 -> 0.279645317544171
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 1.0} , 0 -> 0.255399109741202
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.9} , 1 -> 0.23300284661523601
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.5} , 1 -> 0.18673238514314536
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.7} , 2 -> 0.2247477237768582
# {'M': 4, 'train_size_alpha': 0.7} -> [0.23720676389631998, 0.279645317544171, 0.2247477237768582]
#  {'M': 5, 'train_size_alpha': 0.7} -> thread id = 2532logger {'M': 4, 'train_size_alpha': 0.7}, -> [0.23720676389631998, 0.279645317544171, 0.2247477237768582]
#
# fit
# (5000, 2)
# {'M': 4, 'train_size_alpha': 1.0} , 1 -> 0.24493980832421527
# {'M': 5, 'train_size_alpha': 0.5} , 2 -> 0.20200993148586463
# {'M': 5, 'train_size_alpha': 0.5} -> [0.2061209336429454, 0.18673238514314536, 0.20200993148586463]
#  {'M': 5, 'train_size_alpha': 0.9} -> thread id = 4336logger {'M': 5, 'train_size_alpha': 0.5}, -> [0.2061209336429454, 0.18673238514314536, 0.20200993148586463]
#
# fit
# (5000, 2)
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.9} , 2 -> 0.25848875050424713
# {'M': 4, 'train_size_alpha': 0.9} -> [0.21078455979161972, 0.23300284661523601, 0.25848875050424713]
#  {'M': 5, 'train_size_alpha': 1.0} -> thread id = 30312
# fit
# (5000, 2)
# logger {'M': 4, 'train_size_alpha': 0.9}, -> [0.21078455979161972, 0.23300284661523601, 0.25848875050424713]
# {'M': 4, 'train_size_alpha': 1.0} , 2 -> 0.24890501266129125
# {'M': 4, 'train_size_alpha': 1.0} -> [0.255399109741202, 0.24493980832421527, 0.24890501266129125]
#  {'M': 6, 'train_size_alpha': 0.5} -> thread id = 19248logger {'M': 4, 'train_size_alpha': 1.0}, -> [0.255399109741202, 0.24493980832421527, 0.24890501266129125]
#
# fit
# (5000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.9} , 0 -> 0.18255171536251663
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.7} , 0 -> 0.15909589109479322
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 1.0} , 0 -> 0.2594996730035609
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.5} , 0 -> 0.2425321754016241
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.9} , 1 -> 0.2146497334838642
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.5} , 1 -> 0.16611767232733135
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.7} , 1 -> 0.21296351193436275
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 1.0} , 1 -> 0.24784921303605562
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.5} , 2 -> 0.28869860590352403
# {'M': 6, 'train_size_alpha': 0.5} -> [0.2425321754016241, 0.16611767232733135, 0.28869860590352403]
# logger {'M': 6, 'train_size_alpha': 0.5}, -> [0.2425321754016241, 0.16611767232733135, 0.28869860590352403] {'M': 6, 'train_size_alpha': 0.7} -> thread id = 19248
#
# fit
# (5000, 2)
# {'M': 5, 'train_size_alpha': 0.7} , 2 -> 0.15677150525169692
# {'M': 5, 'train_size_alpha': 0.7} -> [0.15909589109479322, 0.21296351193436275, 0.15677150525169692]
#  {'M': 6, 'train_size_alpha': 0.9} -> thread id = 2532logger {'M': 5, 'train_size_alpha': 0.7}, -> [0.15909589109479322, 0.21296351193436275, 0.15677150525169692]
# fit
# (5000, 2)
#
# {'M': 5, 'train_size_alpha': 0.9} , 2 -> 0.25894501532380615
# {'M': 5, 'train_size_alpha': 0.9} -> [0.18255171536251663, 0.2146497334838642, 0.25894501532380615]
#  {'M': 6, 'train_size_alpha': 1.0} -> thread id = 4336logger {'M': 5, 'train_size_alpha': 0.9}, -> [0.18255171536251663, 0.2146497334838642, 0.25894501532380615]
#
# fit
# (5000, 2)
# {'M': 5, 'train_size_alpha': 1.0} , 2 -> 0.16849633672968964
# {'M': 5, 'train_size_alpha': 1.0} -> [0.2594996730035609, 0.24784921303605562, 0.16849633672968964]
#  {'M': 7, 'train_size_alpha': 0.5} -> thread id = 30312
# fit
# (5000, 2)
# logger {'M': 5, 'train_size_alpha': 1.0}, -> [0.2594996730035609, 0.24784921303605562, 0.16849633672968964]
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.7} , 0 -> 0.24173634057151394
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.9} , 0 -> 0.33432779074009134
# {'M': 7, 'train_size_alpha': 0.5} , 0 -> 0.1419687085767994
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 1.0} , 0 -> 0.19810663010959845
# predict
# (50000, 2)
# {'M': 7, 'train_size_alpha': 0.5} , 1 -> 0.2249279857678573
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.7} , 1 -> 0.22530270897409171
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.9} , 1 -> 0.2562259839536464
# predict
# (50000, 2)
# {'M': 7, 'train_size_alpha': 0.5} , 2 -> 0.19686943681642433
# {'M': 7, 'train_size_alpha': 0.5} -> [0.1419687085767994, 0.2249279857678573, 0.19686943681642433]
#  {'M': 7, 'train_size_alpha': 0.7} -> thread id = 30312logger {'M': 7, 'train_size_alpha': 0.5}, -> [0.1419687085767994, 0.2249279857678573, 0.19686943681642433]
#
# fit
# (5000, 2)
# {'M': 6, 'train_size_alpha': 1.0} , 1 -> 0.2300608693334329
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.7} , 2 -> 0.1785381252113799
# {'M': 6, 'train_size_alpha': 0.7} -> [0.24173634057151394, 0.22530270897409171, 0.1785381252113799]
#  {'M': 7, 'train_size_alpha': 0.9} -> thread id = 19248
# fitlogger {'M': 6, 'train_size_alpha': 0.7}, -> [0.24173634057151394, 0.22530270897409171, 0.1785381252113799]
#
# (5000, 2)
# {'M': 6, 'train_size_alpha': 0.9} , 2 -> 0.24214627688187454
# {'M': 6, 'train_size_alpha': 0.9} -> [0.33432779074009134, 0.2562259839536464, 0.24214627688187454]
#  {'M': 7, 'train_size_alpha': 1.0} -> thread id = 2532logger {'M': 6, 'train_size_alpha': 0.9}, -> [0.33432779074009134, 0.2562259839536464, 0.24214627688187454]
#
# fit
# (5000, 2)
# {'M': 6, 'train_size_alpha': 1.0} , 2 -> 0.22273533602675982
# {'M': 6, 'train_size_alpha': 1.0} -> [0.19810663010959845, 0.2300608693334329, 0.22273533602675982]
#  {'M': 8, 'train_size_alpha': 0.5} -> thread id = 4336
# fit
# (5000, 2)
# logger {'M': 6, 'train_size_alpha': 1.0}, -> [0.19810663010959845, 0.2300608693334329, 0.22273533602675982]
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 7, 'train_size_alpha': 0.7} , 0 -> 0.1349551190770814
# predict
# (50000, 2)
# {'M': 7, 'train_size_alpha': 0.9} , 0 -> 0.23855554430892592
# predict
# (50000, 2)
# {'M': 8, 'train_size_alpha': 0.5} , 0 -> 0.20598380349614945
# predict
# (50000, 2)
# {'M': 7, 'train_size_alpha': 0.7} , 1 -> 0.1473547430320229
# predict
# (50000, 2)
# {'M': 8, 'train_size_alpha': 0.5} , 1 -> 0.21223570638202469
# {'M': 7, 'train_size_alpha': 1.0} , 0 -> 0.1906853167351773
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 7, 'train_size_alpha': 0.9} , 1 -> 0.24123996550959814
# predict
# (50000, 2)
# {'M': 7, 'train_size_alpha': 0.7} , 2 -> 0.18215470796430797
# {'M': 7, 'train_size_alpha': 0.7} -> [0.1349551190770814, 0.1473547430320229, 0.18215470796430797]
#  {'M': 8, 'train_size_alpha': 0.7} -> thread id = 30312logger {'M': 7, 'train_size_alpha': 0.7}, -> [0.1349551190770814, 0.1473547430320229, 0.18215470796430797]
#
# fit
# (5000, 2)
# {'M': 8, 'train_size_alpha': 0.5} , 2 -> 0.2496936266393877
# {'M': 8, 'train_size_alpha': 0.5} -> [0.20598380349614945, 0.21223570638202469, 0.2496936266393877]
# logger {'M': 8, 'train_size_alpha': 0.5}, -> [0.20598380349614945, 0.21223570638202469, 0.2496936266393877]
#  {'M': 8, 'train_size_alpha': 0.9} -> thread id = 4336
# fit
# (5000, 2)
# {'M': 7, 'train_size_alpha': 1.0} , 1 -> 0.18994780719916898
# predict
# (50000, 2)
# {'M': 7, 'train_size_alpha': 0.9} , 2 -> 0.18045735037454724
# {'M': 7, 'train_size_alpha': 0.9} -> [0.23855554430892592, 0.24123996550959814, 0.18045735037454724]
#  {'M': 8, 'train_size_alpha': 1.0} -> thread id = 19248logger {'M': 7, 'train_size_alpha': 0.9}, -> [0.23855554430892592, 0.24123996550959814, 0.18045735037454724]
#
# fit
# (5000, 2)
# {'M': 7, 'train_size_alpha': 1.0} , 2 -> 0.23324569544987087
# {'M': 7, 'train_size_alpha': 1.0} -> [0.1906853167351773, 0.18994780719916898, 0.23324569544987087]
#  {'M': 1, 'train_size_alpha': 0.5} -> thread id = 2532logger {'M': 7, 'train_size_alpha': 1.0}, -> [0.1906853167351773, 0.18994780719916898, 0.23324569544987087]
#
# fit
# (5000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.5} , 0 -> 0.17361323933488954
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.5} , 1 -> 0.17005781283589957
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.5} , 2 -> 0.15043844212212637
# {'M': 1, 'train_size_alpha': 0.5} -> [0.17361323933488954, 0.17005781283589957, 0.15043844212212637]
#  {'M': 1, 'train_size_alpha': 0.7} -> thread id = 2532logger {'M': 1, 'train_size_alpha': 0.5}, -> [0.17361323933488954, 0.17005781283589957, 0.15043844212212637]
# fit
# (5000, 2)
#
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.7} , 0 -> 0.2290461819621092
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.7} , 1 -> 0.19398924948139423
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.7} , 2 -> 0.22985572751717684
# {'M': 1, 'train_size_alpha': 0.7} -> [0.2290461819621092, 0.19398924948139423, 0.22985572751717684]
#  {'M': 1, 'train_size_alpha': 0.9} -> thread id = 2532
# logger {'M': 1, 'train_size_alpha': 0.7}, -> [0.2290461819621092, 0.19398924948139423, 0.22985572751717684]
# fit
# (5000, 2)
# {'M': 8, 'train_size_alpha': 0.9} , 0 -> 0.15873312675861187
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.9} , 0 -> 0.18376331996696993
# predict
# (50000, 2)
# {'M': 8, 'train_size_alpha': 0.7} , 0 -> 0.20225833514232666{'M': 1, 'train_size_alpha': 0.9} , 1 -> 0.17088990126740447
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.9} , 2 -> 0.18781109118281294
# {'M': 1, 'train_size_alpha': 0.9} -> [0.18376331996696993, 0.17088990126740447, 0.18781109118281294]
#  {'M': 1, 'train_size_alpha': 1.0} -> thread id = 2532
# logger {'M': 1, 'train_size_alpha': 0.9}, -> [0.18376331996696993, 0.17088990126740447, 0.18781109118281294]
# fit
# (5000, 2)
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 1.0} , 0 -> 0.23826376028536506
# predict
# (50000, 2)
# {'M': 8, 'train_size_alpha': 1.0} , 0 -> 0.3399799970953494{'M': 1, 'train_size_alpha': 1.0} , 1 -> 0.22302788473666652
#
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 1.0} , 2 -> 0.21283132590257609
# {'M': 1, 'train_size_alpha': 1.0} -> [0.23826376028536506, 0.22302788473666652, 0.21283132590257609]
#  {'M': 2, 'train_size_alpha': 0.5} -> thread id = 2532
# logger {'M': 1, 'train_size_alpha': 1.0}, -> [0.23826376028536506, 0.22302788473666652, 0.21283132590257609]fit
# (5000, 2)
#
# {'M': 8, 'train_size_alpha': 0.7} , 1 -> 0.2667579573512467
# predict
# (50000, 2)
# {'M': 8, 'train_size_alpha': 0.9} , 1 -> 0.15730128980588498
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.5} , 0 -> 0.15058417078287983
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.5} , 1 -> 0.20148275573354366
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.5} , 2 -> 0.1705040466401511
# {'M': 2, 'train_size_alpha': 0.5} -> [0.15058417078287983, 0.20148275573354366, 0.1705040466401511]
#  {'M': 2, 'train_size_alpha': 0.7} -> thread id = 2532logger {'M': 2, 'train_size_alpha': 0.5}, -> [0.15058417078287983, 0.20148275573354366, 0.1705040466401511]
#
# fit
# (5000, 2)
# {'M': 8, 'train_size_alpha': 0.7} , 2 -> 0.23107544041641725
# {'M': 8, 'train_size_alpha': 0.7} -> [0.20225833514232666, 0.2667579573512467, 0.23107544041641725]
#  {'M': 2, 'train_size_alpha': 0.9} -> thread id = 30312logger {'M': 8, 'train_size_alpha': 0.7}, -> [0.20225833514232666, 0.2667579573512467, 0.23107544041641725]
#
# fit
# (5000, 2)
# {'M': 8, 'train_size_alpha': 1.0} , 1 -> 0.26100503305626716
# predictpredict
# (50000, 2)
#
# (50000, 2)
# {'M': 8, 'train_size_alpha': 0.9} , 2 -> 0.14293818328727054
# {'M': 8, 'train_size_alpha': 0.9} -> [0.15873312675861187, 0.15730128980588498, 0.14293818328727054]
#  {'M': 2, 'train_size_alpha': 1.0} -> thread id = 4336
# logger {'M': 8, 'train_size_alpha': 0.9}, -> [0.15873312675861187, 0.15730128980588498, 0.14293818328727054]fit
# (5000, 2)
#
# {'M': 2, 'train_size_alpha': 0.7} , 0 -> 0.20273084230646132
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.7} , 1 -> 0.21678851556130224
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.9} , 0 -> 0.1673571745481178
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.7} , 2 -> 0.17867952105539092
# {'M': 2, 'train_size_alpha': 0.7} -> [0.20273084230646132, 0.21678851556130224, 0.17867952105539092]
#  {'M': 3, 'train_size_alpha': 0.5} -> thread id = 2532logger {'M': 2, 'train_size_alpha': 0.7}, -> [0.20273084230646132, 0.21678851556130224, 0.17867952105539092]
#
# fit
# (5000, 2)
# {'M': 2, 'train_size_alpha': 1.0} , 0 -> 0.2574783367725038
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.9} , 1 -> 0.16944061459328805
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.9} , 2 -> 0.13242618764664071
# {'M': 2, 'train_size_alpha': 0.9} -> [0.1673571745481178, 0.16944061459328805, 0.13242618764664071]
# logger {'M': 2, 'train_size_alpha': 0.9}, -> [0.1673571745481178, 0.16944061459328805, 0.13242618764664071] {'M': 3, 'train_size_alpha': 0.7} -> thread id = 30312
#
# fit
# (5000, 2)
# {'M': 2, 'train_size_alpha': 1.0} , 1 -> 0.21324615593219198
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.5} , 0 -> 0.22040252524112913
# predict
# (50000, 2)
# {'M': 8, 'train_size_alpha': 1.0} , 2 -> 0.2033965931716335
# {'M': 8, 'train_size_alpha': 1.0} -> [0.3399799970953494, 0.26100503305626716, 0.2033965931716335]
#  {'M': 3, 'train_size_alpha': 0.9} -> thread id = 19248logger {'M': 8, 'train_size_alpha': 1.0}, -> [0.3399799970953494, 0.26100503305626716, 0.2033965931716335]
#
# fit
# (5000, 2)
# {'M': 3, 'train_size_alpha': 0.5} , 1 -> 0.20755332997148707
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 1.0} , 2 -> 0.29406828207076546
# {'M': 2, 'train_size_alpha': 1.0} -> [0.2574783367725038, 0.21324615593219198, 0.29406828207076546]
#  {'M': 3, 'train_size_alpha': 1.0} -> thread id = 4336
# fit
# (5000, 2)
# logger {'M': 2, 'train_size_alpha': 1.0}, -> [0.2574783367725038, 0.21324615593219198, 0.29406828207076546]
# {'M': 3, 'train_size_alpha': 0.5} , 2 -> 0.19525492966772012
# {'M': 3, 'train_size_alpha': 0.5} -> [0.22040252524112913, 0.20755332997148707, 0.19525492966772012]
#  {'M': 4, 'train_size_alpha': 0.5} -> thread id = 2532logger {'M': 3, 'train_size_alpha': 0.5}, -> [0.22040252524112913, 0.20755332997148707, 0.19525492966772012]
# fit
#
# (5000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.7} , 0 -> 0.2828094884253296
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.9} , 0 -> 0.1765273905004401
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.7} , 1 -> 0.23281924694042083
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.5} , 0 -> 0.1746603269963504
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 1.0} , 0 -> 0.20938786410143798
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.9} , 1 -> 0.2619743170329869
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.7} , 2 -> 0.25217510366147344
# {'M': 3, 'train_size_alpha': 0.7} -> [0.2828094884253296, 0.23281924694042083, 0.25217510366147344]
#  {'M': 4, 'train_size_alpha': 0.7} -> thread id = 30312logger {'M': 3, 'train_size_alpha': 0.7}, -> [0.2828094884253296, 0.23281924694042083, 0.25217510366147344]
#
# fit
# (5000, 2)
# {'M': 4, 'train_size_alpha': 0.5} , 1 -> 0.17883063539149088
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 1.0} , 1 -> 0.19680919361218388
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.9} , 2 -> 0.22770305752126016
# {'M': 3, 'train_size_alpha': 0.9} -> [0.1765273905004401, 0.2619743170329869, 0.22770305752126016]
#  {'M': 4, 'train_size_alpha': 0.9} -> thread id = 19248logger {'M': 3, 'train_size_alpha': 0.9}, -> [0.1765273905004401, 0.2619743170329869, 0.22770305752126016]
#
# fit
# (5000, 2)
# {'M': 4, 'train_size_alpha': 0.5} , 2 -> 0.1452594934390913
# {'M': 4, 'train_size_alpha': 0.5} -> [0.1746603269963504, 0.17883063539149088, 0.1452594934390913]
#  {'M': 4, 'train_size_alpha': 1.0} -> thread id = 2532
# fit
# (5000, 2)
# logger {'M': 4, 'train_size_alpha': 0.5}, -> [0.1746603269963504, 0.17883063539149088, 0.1452594934390913]
# {'M': 3, 'train_size_alpha': 1.0} , 2 -> 0.22919185912719325
# {'M': 3, 'train_size_alpha': 1.0} -> [0.20938786410143798, 0.19680919361218388, 0.22919185912719325]
#  {'M': 5, 'train_size_alpha': 0.5} -> thread id = 4336
# fit
# (5000, 2)
# logger {'M': 3, 'train_size_alpha': 1.0}, -> [0.20938786410143798, 0.19680919361218388, 0.22919185912719325]
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.7} , 0 -> 0.3313178114280212
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.7} , 1 -> 0.258250123291359
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.9} , 0 -> 0.25057752900771296
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.5} , 0 -> 0.1351611919100459
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 1.0} , 0 -> 0.17018600022043812
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.7} , 2 -> 0.21241797695814804
# {'M': 4, 'train_size_alpha': 0.7} -> [0.3313178114280212, 0.258250123291359, 0.21241797695814804]
# logger {'M': 4, 'train_size_alpha': 0.7}, -> [0.3313178114280212, 0.258250123291359, 0.21241797695814804] {'M': 5, 'train_size_alpha': 0.7} -> thread id = 30312
#
# fit
# (5000, 2)
# {'M': 5, 'train_size_alpha': 0.5} , 1 -> 0.1618291660965056
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.9} , 1 -> 0.24094789602710187
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.5} , 2 -> 0.13582185063053642
# {'M': 5, 'train_size_alpha': 0.5} -> [0.1351611919100459, 0.1618291660965056, 0.13582185063053642]
# logger {'M': 5, 'train_size_alpha': 0.5}, -> [0.1351611919100459, 0.1618291660965056, 0.13582185063053642] {'M': 5, 'train_size_alpha': 0.9} -> thread id = 4336
#
# fit
# (5000, 2)
# {'M': 4, 'train_size_alpha': 1.0} , 1 -> 0.17609008226876188
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.9} , 2 -> 0.17423794088215236
# {'M': 4, 'train_size_alpha': 0.9} -> [0.25057752900771296, 0.24094789602710187, 0.17423794088215236]
#  {'M': 5, 'train_size_alpha': 1.0} -> thread id = 19248logger {'M': 4, 'train_size_alpha': 0.9}, -> [0.25057752900771296, 0.24094789602710187, 0.17423794088215236]
# fit
# (5000, 2)
#
# {'M': 4, 'train_size_alpha': 1.0} , 2 -> 0.15960210950977696
# {'M': 4, 'train_size_alpha': 1.0} -> [0.17018600022043812, 0.17609008226876188, 0.15960210950977696]
#  {'M': 6, 'train_size_alpha': 0.5} -> thread id = 2532
# logger {'M': 4, 'train_size_alpha': 1.0}, -> [0.17018600022043812, 0.17609008226876188, 0.15960210950977696]fit
# (5000, 2)
#
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.7} , 0 -> 0.23730875663959133
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.9} , 0 -> 0.19340895250252688
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.7} , 1 -> 0.2354526563095605
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.5} , 0 -> 0.18356124792347703
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 1.0} , 0 -> 0.18367402344398917
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.7} , 2 -> 0.29262973568782047
# {'M': 5, 'train_size_alpha': 0.7} -> [0.23730875663959133, 0.2354526563095605, 0.29262973568782047]
#  {'M': 6, 'train_size_alpha': 0.7} -> thread id = 30312
# logger {'M': 5, 'train_size_alpha': 0.7}, -> [0.23730875663959133, 0.2354526563095605, 0.29262973568782047]
# fit
# (5000, 2)
# {'M': 5, 'train_size_alpha': 0.9} , 1 -> 0.18547346762389114
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.5} , 1 -> 0.20208563323941778
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.5} , 2 -> 0.18977742573462283
# {'M': 6, 'train_size_alpha': 0.5} -> [0.18356124792347703, 0.20208563323941778, 0.18977742573462283]
#  {'M': 6, 'train_size_alpha': 0.9} -> thread id = 2532
# fit
# (5000, 2)
# logger {'M': 6, 'train_size_alpha': 0.5}, -> [0.18356124792347703, 0.20208563323941778, 0.18977742573462283]
# {'M': 5, 'train_size_alpha': 1.0} , 1 -> 0.13069179137007
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.9} , 2 -> 0.1867511579447145
# {'M': 5, 'train_size_alpha': 0.9} -> [0.19340895250252688, 0.18547346762389114, 0.1867511579447145]
#  {'M': 6, 'train_size_alpha': 1.0} -> thread id = 4336
# fit
# (5000, 2)
# logger {'M': 5, 'train_size_alpha': 0.9}, -> [0.19340895250252688, 0.18547346762389114, 0.1867511579447145]
# {'M': 5, 'train_size_alpha': 1.0} , 2 -> 0.19663251925644257
# {'M': 5, 'train_size_alpha': 1.0} -> [0.18367402344398917, 0.13069179137007, 0.19663251925644257]
#  {'M': 7, 'train_size_alpha': 0.5} -> thread id = 19248logger {'M': 5, 'train_size_alpha': 1.0}, -> [0.18367402344398917, 0.13069179137007, 0.19663251925644257]
#
# fit
# (5000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.7} , 0 -> 0.2613423875624043
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.7} , 1 -> 0.2665163015014568
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.9} , 0 -> 0.14885778644546896
# predict
# (50000, 2)
# {'M': 7, 'train_size_alpha': 0.5} , 0 -> 0.18192285350283088
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 1.0} , 0 -> 0.23995899219244549
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.7} , 2 -> 0.2086616986375105
# {'M': 6, 'train_size_alpha': 0.7} -> [0.2613423875624043, 0.2665163015014568, 0.2086616986375105]
#  {'M': 7, 'train_size_alpha': 0.7} -> thread id = 30312
# logger {'M': 6, 'train_size_alpha': 0.7}, -> [0.2613423875624043, 0.2665163015014568, 0.2086616986375105]fit
#
# (5000, 2)
# {'M': 7, 'train_size_alpha': 0.5} , 1 -> 0.16562778326444375
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.9} , 1 -> 0.12901745318157082
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 1.0} , 1 -> 0.31767443842696486
# predict
# (50000, 2)
# {'M': 7, 'train_size_alpha': 0.5} , 2 -> 0.1963331544667566
# {'M': 7, 'train_size_alpha': 0.5} -> [0.18192285350283088, 0.16562778326444375, 0.1963331544667566]
#  {'M': 7, 'train_size_alpha': 0.9} -> thread id = 19248logger {'M': 7, 'train_size_alpha': 0.5}, -> [0.18192285350283088, 0.16562778326444375, 0.1963331544667566]
# fit
#
# (5000, 2)
# {'M': 6, 'train_size_alpha': 0.9} , 2 -> 0.18377238332085816
# {'M': 6, 'train_size_alpha': 0.9} -> [0.14885778644546896, 0.12901745318157082, 0.18377238332085816]
#  {'M': 7, 'train_size_alpha': 1.0} -> thread id = 2532
# logger {'M': 6, 'train_size_alpha': 0.9}, -> [0.14885778644546896, 0.12901745318157082, 0.18377238332085816]fit
# (5000, 2)
#
# {'M': 6, 'train_size_alpha': 1.0} , 2 -> 0.251650708818354
# {'M': 6, 'train_size_alpha': 1.0} -> [0.23995899219244549, 0.31767443842696486, 0.251650708818354]
#  {'M': 8, 'train_size_alpha': 0.5} -> thread id = 4336logger {'M': 6, 'train_size_alpha': 1.0}, -> [0.23995899219244549, 0.31767443842696486, 0.251650708818354]
#
# fit
# (5000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 7, 'train_size_alpha': 0.7} , 0 -> 0.15414995806663373
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 7, 'train_size_alpha': 0.9} , 0 -> 0.17123391598493642
# predict
# (50000, 2)
# {'M': 7, 'train_size_alpha': 0.7} , 1 -> 0.12237322081695327
# predict
# (50000, 2)
# {'M': 8, 'train_size_alpha': 0.5} , 0 -> 0.1940534904554768
# predict
# (50000, 2)
# {'M': 7, 'train_size_alpha': 1.0} , 0 -> 0.16246237234904362
# predict
# (50000, 2)
# {'M': 7, 'train_size_alpha': 0.7} , 2 -> 0.15659005488945849
# {'M': 7, 'train_size_alpha': 0.7} -> [0.15414995806663373, 0.12237322081695327, 0.15659005488945849]
#  {'M': 8, 'train_size_alpha': 0.7} -> thread id = 30312logger {'M': 7, 'train_size_alpha': 0.7}, -> [0.15414995806663373, 0.12237322081695327, 0.15659005488945849]
#
# fit
# (5000, 2)
# {'M': 8, 'train_size_alpha': 0.5} , 1 -> 0.21200394162473218
# predict
# (50000, 2)
# {'M': 7, 'train_size_alpha': 0.9} , 1 -> 0.16603891903498078
# predict
# (50000, 2)
# {'M': 8, 'train_size_alpha': 0.5} , 2 -> 0.18953709383295791
# {'M': 8, 'train_size_alpha': 0.5} -> [0.1940534904554768, 0.21200394162473218, 0.18953709383295791]
#  {'M': 8, 'train_size_alpha': 0.9} -> thread id = 4336
# logger {'M': 8, 'train_size_alpha': 0.5}, -> [0.1940534904554768, 0.21200394162473218, 0.18953709383295791]fit
#
# (5000, 2)
# {'M': 7, 'train_size_alpha': 1.0} , 1 -> 0.14279638688161989
# predict
# (50000, 2)
# {'M': 7, 'train_size_alpha': 0.9} , 2 -> 0.14646290795237518
# {'M': 7, 'train_size_alpha': 0.9} -> [0.17123391598493642, 0.16603891903498078, 0.14646290795237518]
#  {'M': 8, 'train_size_alpha': 1.0} -> thread id = 19248
# fit
# (5000, 2)
# logger {'M': 7, 'train_size_alpha': 0.9}, -> [0.17123391598493642, 0.16603891903498078, 0.14646290795237518]
# {'M': 7, 'train_size_alpha': 1.0} , 2 -> 0.18910689556102503
# {'M': 7, 'train_size_alpha': 1.0} -> [0.16246237234904362, 0.14279638688161989, 0.18910689556102503]
#  {'M': 1, 'train_size_alpha': 0.5} -> thread id = 2532logger {'M': 7, 'train_size_alpha': 1.0}, -> [0.16246237234904362, 0.14279638688161989, 0.18910689556102503]
# fit
# (5000, 2)
#
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.5} , 0 -> 0.2015544601976558
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.5} , 1 -> 0.12514034364108487
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.5} , 2 -> 0.10826450285459766
# {'M': 1, 'train_size_alpha': 0.5} -> [0.2015544601976558, 0.12514034364108487, 0.10826450285459766]
#  {'M': 1, 'train_size_alpha': 0.7} -> thread id = 2532
# logger {'M': 1, 'train_size_alpha': 0.5}, -> [0.2015544601976558, 0.12514034364108487, 0.10826450285459766]
# fit
# (5000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.7} , 0 -> 0.21425710363527267
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 8, 'train_size_alpha': 0.7} , 0 -> 0.25391039009714883
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.7} , 1 -> 0.22858541936457588
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.7} , 2 -> 0.24861114043836088
# {'M': 1, 'train_size_alpha': 0.7} -> [0.21425710363527267, 0.22858541936457588, 0.24861114043836088]
#  {'M': 1, 'train_size_alpha': 0.9} -> thread id = 2532logger {'M': 1, 'train_size_alpha': 0.7}, -> [0.21425710363527267, 0.22858541936457588, 0.24861114043836088]
#
# fit
# (5000, 2)
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.9} , 0 -> 0.15993114142242784
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.9} , 1 -> 0.12012557320655037
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 0.9} , 2 -> 0.14422471086902347
# {'M': 1, 'train_size_alpha': 0.9} -> [0.15993114142242784, 0.12012557320655037, 0.14422471086902347]
#  {'M': 1, 'train_size_alpha': 1.0} -> thread id = 2532logger {'M': 1, 'train_size_alpha': 0.9}, -> [0.15993114142242784, 0.12012557320655037, 0.14422471086902347]
#
# fit
# (5000, 2)
# {'M': 8, 'train_size_alpha': 0.7} , 1 -> 0.20618155322286602
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 8, 'train_size_alpha': 0.9} , 0 -> 0.24089850181115466
# predict
# (50000, 2)
# {'M': 8, 'train_size_alpha': 1.0}
# Traceback (most recent call last):
#   File "C:\Users\thoma\School\Machine_learning\ML-Project2\aggregating\gridsearch.py", line 47, in evaluate_model
#     y_hat = model.predict(Flattened_X_test)
#   File "C:\Users\thoma\School\Machine_learning\ML-Project2\aggregating\models.py", line 27, in predict
#     predictions = predictions + self.predictors[i].predict(X)
#   File "c:\users\thoma\appdata\local\programs\python\python37\lib\site-packages\sklearn\gaussian_process\_gpr.py", line 338, in predict
#     K_trans = self.kernel_(X, self.X_train_)
#   File "c:\users\thoma\appdata\local\programs\python\python37\lib\site-packages\sklearn\gaussian_process\kernels.py", line 758, in __call__
#     return self.k1(X, Y) + self.k2(X, Y)
#   File "c:\users\thoma\appdata\local\programs\python\python37\lib\site-packages\sklearn\gaussian_process\kernels.py", line 1435, in __call__
#     K = np.exp(-.5 * dists)
# MemoryError: Unable to allocate array with shape (50000, 5000) and data type float64
# logger {'M': 8, 'train_size_alpha': 1.0}, -> None {'M': 2, 'train_size_alpha': 0.5} -> thread id = 19248
#
# fit
# (5000, 2)
# {'M': 1, 'train_size_alpha': 1.0} , 0 -> 0.20726015600341657
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 1.0} , 1 -> 0.20115846907627224
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.5} , 0 -> 0.1656885904550893
# predict
# (50000, 2)
# {'M': 1, 'train_size_alpha': 1.0} , 2 -> 0.2145047751110511
# {'M': 1, 'train_size_alpha': 1.0} -> [0.20726015600341657, 0.20115846907627224, 0.2145047751110511]
#  {'M': 2, 'train_size_alpha': 0.7} -> thread id = 2532logger {'M': 1, 'train_size_alpha': 1.0}, -> [0.20726015600341657, 0.20115846907627224, 0.2145047751110511]
#
# fit
# (5000, 2)
# {'M': 2, 'train_size_alpha': 0.5} , 1 -> 0.14133020760855625
# predict
# (50000, 2)
# {'M': 8, 'train_size_alpha': 0.7} , 2 -> 0.22907781878972683
# {'M': 8, 'train_size_alpha': 0.7} -> [0.25391039009714883, 0.20618155322286602, 0.22907781878972683]
#  {'M': 2, 'train_size_alpha': 0.9} -> thread id = 30312
# fit
# (5000, 2)
# logger {'M': 8, 'train_size_alpha': 0.7}, -> [0.25391039009714883, 0.20618155322286602, 0.22907781878972683]
# {'M': 2, 'train_size_alpha': 0.5} , 2 -> 0.16637667587934243
# {'M': 2, 'train_size_alpha': 0.5} -> [0.1656885904550893, 0.14133020760855625, 0.16637667587934243]
#  {'M': 2, 'train_size_alpha': 1.0} -> thread id = 19248
# logger {'M': 2, 'train_size_alpha': 0.5}, -> [0.1656885904550893, 0.14133020760855625, 0.16637667587934243]fit
# (5000, 2)
#
# predict
# (50000, 2)
# {'M': 8, 'train_size_alpha': 0.9} , 1 -> 0.20918462929738035
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.7} , 0 -> 0.12325326706184328
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.7} , 1 -> 0.21081858855473656
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.9} , 0 -> 0.1607972740864905
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 1.0} , 0 -> 0.21499490816727926
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.7} , 2 -> 0.21952381130334916
# {'M': 2, 'train_size_alpha': 0.7} -> [0.12325326706184328, 0.21081858855473656, 0.21952381130334916]
#  {'M': 3, 'train_size_alpha': 0.5} -> thread id = 2532logger {'M': 2, 'train_size_alpha': 0.7}, -> [0.12325326706184328, 0.21081858855473656, 0.21952381130334916]
#
# fit
# (5000, 2)
# {'M': 2, 'train_size_alpha': 0.9} , 1 -> 0.18657294271325076
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 1.0} , 1 -> 0.18897823386368826
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 0.9} , 2 -> 0.14126048392291513
# {'M': 2, 'train_size_alpha': 0.9} -> [0.1607972740864905, 0.18657294271325076, 0.14126048392291513]
#  {'M': 3, 'train_size_alpha': 0.7} -> thread id = 30312logger {'M': 2, 'train_size_alpha': 0.9}, -> [0.1607972740864905, 0.18657294271325076, 0.14126048392291513]
#
# fit
# (5000, 2)
# {'M': 8, 'train_size_alpha': 0.9} , 2 -> 0.16147303581081243
# {'M': 8, 'train_size_alpha': 0.9} -> [0.24089850181115466, 0.20918462929738035, 0.16147303581081243]
#  {'M': 3, 'train_size_alpha': 0.9} -> thread id = 4336logger {'M': 8, 'train_size_alpha': 0.9}, -> [0.24089850181115466, 0.20918462929738035, 0.16147303581081243]
#
# fit
# (5000, 2)
# {'M': 3, 'train_size_alpha': 0.5} , 0 -> 0.1842923006168177
# predict
# (50000, 2)
# {'M': 2, 'train_size_alpha': 1.0} , 2 -> 0.22210928598572607
# {'M': 2, 'train_size_alpha': 1.0} -> [0.21499490816727926, 0.18897823386368826, 0.22210928598572607]
#  {'M': 3, 'train_size_alpha': 1.0} -> thread id = 19248
# fit
# (5000, 2)
# logger {'M': 2, 'train_size_alpha': 1.0}, -> [0.21499490816727926, 0.18897823386368826, 0.22210928598572607]
# {'M': 3, 'train_size_alpha': 0.5} , 1 -> 0.17657531494981393
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.5} , 2 -> 0.22121282269751644
# {'M': 3, 'train_size_alpha': 0.5} -> [0.1842923006168177, 0.17657531494981393, 0.22121282269751644]
#  {'M': 4, 'train_size_alpha': 0.5} -> thread id = 2532
# fit
# (5000, 2)
# logger {'M': 3, 'train_size_alpha': 0.5}, -> [0.1842923006168177, 0.17657531494981393, 0.22121282269751644]
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.7} , 0 -> 0.17208051591799653
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.9} , 0 -> 0.2005938701249383
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 1.0} , 0 -> 0.1891709878773372
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.7} , 1 -> 0.19259081593284227
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.5} , 0 -> 0.13202804380287844
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.9} , 1 -> 0.1884740829380623
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.7} , 2 -> 0.23848593020736047
# {'M': 3, 'train_size_alpha': 0.7} -> [0.17208051591799653, 0.19259081593284227, 0.23848593020736047]
#  {'M': 4, 'train_size_alpha': 0.7} -> thread id = 30312logger {'M': 3, 'train_size_alpha': 0.7}, -> [0.17208051591799653, 0.19259081593284227, 0.23848593020736047]
#
# fit
# (5000, 2)
# {'M': 4, 'train_size_alpha': 0.5} , 1 -> 0.17347154385965374
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 1.0} , 1 -> 0.19595227004241217
# predict
# (50000, 2)
# {'M': 3, 'train_size_alpha': 0.9} , 2 -> 0.1878987334928843
# {'M': 3, 'train_size_alpha': 0.9} -> [0.2005938701249383, 0.1884740829380623, 0.1878987334928843]
#  {'M': 4, 'train_size_alpha': 0.9} -> thread id = 4336logger {'M': 3, 'train_size_alpha': 0.9}, -> [0.2005938701249383, 0.1884740829380623, 0.1878987334928843]
#
# fit
# (5000, 2)
# {'M': 4, 'train_size_alpha': 0.5} , 2 -> 0.1388903037803171
# {'M': 4, 'train_size_alpha': 0.5} -> [0.13202804380287844, 0.17347154385965374, 0.1388903037803171]
#  {'M': 4, 'train_size_alpha': 1.0} -> thread id = 2532logger {'M': 4, 'train_size_alpha': 0.5}, -> [0.13202804380287844, 0.17347154385965374, 0.1388903037803171]
#
# fit
# (5000, 2)
# {'M': 3, 'train_size_alpha': 1.0} , 2 -> 0.24488532931465654
# {'M': 3, 'train_size_alpha': 1.0} -> [0.1891709878773372, 0.19595227004241217, 0.24488532931465654]
#  {'M': 5, 'train_size_alpha': 0.5} -> thread id = 19248logger {'M': 3, 'train_size_alpha': 1.0}, -> [0.1891709878773372, 0.19595227004241217, 0.24488532931465654]
#
# fit
# (5000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.7} , 0 -> 0.17125646314530435
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.5} , 0 -> 0.15445545597348692
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.9} , 0 -> 0.20145072609830472
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 1.0} , 0 -> 0.1216872462001219
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.7} , 1 -> 0.2359296407860907
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.5} , 1 -> 0.17006731479909745
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.7} , 2 -> 0.1970961383912652
# {'M': 4, 'train_size_alpha': 0.7} -> [0.17125646314530435, 0.2359296407860907, 0.1970961383912652]
# logger {'M': 4, 'train_size_alpha': 0.7}, -> [0.17125646314530435, 0.2359296407860907, 0.1970961383912652] {'M': 5, 'train_size_alpha': 0.7} -> thread id = 30312
#
# fit
# (5000, 2)
# {'M': 4, 'train_size_alpha': 0.9} , 1 -> 0.18210480616301616
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.5} , 2 -> 0.18681683651694717
# {'M': 5, 'train_size_alpha': 0.5} -> [0.15445545597348692, 0.17006731479909745, 0.18681683651694717]
#  {'M': 5, 'train_size_alpha': 0.9} -> thread id = 19248logger {'M': 5, 'train_size_alpha': 0.5}, -> [0.15445545597348692, 0.17006731479909745, 0.18681683651694717]
# fit
#
# (5000, 2)
# {'M': 4, 'train_size_alpha': 1.0} , 1 -> 0.13274552627868894
# predict
# (50000, 2)
# {'M': 4, 'train_size_alpha': 0.9} , 2 -> 0.22682201805293123
# {'M': 4, 'train_size_alpha': 0.9} -> [0.20145072609830472, 0.18210480616301616, 0.22682201805293123]
#  {'M': 5, 'train_size_alpha': 1.0} -> thread id = 4336
# logger {'M': 4, 'train_size_alpha': 0.9}, -> [0.20145072609830472, 0.18210480616301616, 0.22682201805293123]
# fit
# (5000, 2)
# {'M': 4, 'train_size_alpha': 1.0} , 2 -> 0.1393489111489158
# {'M': 4, 'train_size_alpha': 1.0} -> [0.1216872462001219, 0.13274552627868894, 0.1393489111489158]
#  {'M': 6, 'train_size_alpha': 0.5} -> thread id = 2532logger {'M': 4, 'train_size_alpha': 1.0}, -> [0.1216872462001219, 0.13274552627868894, 0.1393489111489158]
#
# fit
# (5000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.9} , 0 -> 0.22711624591137297
# predict
# (50000, 2)
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.7} , 0 -> 0.22698790625224324
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.5} , 0 -> 0.15831020113868247
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.9} , 1 -> 0.14383997465022963
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.7} , 1 -> 0.17058423594741856
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 1.0} , 0 -> 0.20502865297231423
# predict
# (50000, 2)
# {'M': 6, 'train_size_alpha': 0.5} , 1 -> 0.1674200007883071
# predict
# (50000, 2)
# {'M': 5, 'train_size_alpha': 0.7} , 2 -> 0.2334779827043963
# {'M': 5, 'train_size_alpha': 0.7} -> [0.22698790625224324, 0.17058423594741856, 0.2334779827043963]
# logger {'M': 5, 'train_size_alpha': 0.7}, -> [0.22698790625224324, 0.17058423594741856, 0.2334779827043963] {'M': 6, 'train_size_alpha': 0.7} -> thread id = 30312
#
# fit
# (5000, 2)
# {'M': 6, 'train_size_alpha': 0.5} , 2 -> 0.1836707266996896
# {'M': 6, 'train_size_alpha': 0.5} -> [0.15831020113868247, 0.1674200007883071, 0.1836707266996896]
#  {'M': 6, 'train_size_alpha': 0.9} -> thread id = 2532
# fit
# (5000, 2)
# logger {'M': 6, 'train_size_alpha': 0.5}, -> [0.15831020113868247, 0.1674200007883071, 0.1836707266996896]
# {'M': 5, 'train_size_alpha': 0.9} , 2 -> 0.15613207954144076
# {'M': 5, 'train_size_alpha': 0.9} -> [0.22711624591137297, 0.14383997465022963, 0.15613207954144076]
#  {'M': 6, 'train_size_alpha': 1.0} -> thread id = 19248logger {'M': 5, 'train_size_alpha': 0.9}, -> [0.22711624591137297, 0.14383997465022963, 0.15613207954144076]
# fit
# (5000, 2)
#
# {'M': 5, 'train_size_alpha': 1.0} , 1 -> 0.16262669066726504
# predict
# (50000, 2)

# %%
converted_results = np.ones((len(M_grid),len(alpha_grid),trials))*(-1)
for item in results:
    print(item)
    converted_results[M_grid.index(item[0]),alpha_grid.index(item[1])] = item[2]

print(converted_results.shape)
print(converted_results)

# %%
masked_results= np.ma.masked_where(converted_results <= 0.0,converted_results) # some runs have been aborted every now and then -> filter them out
means = masked_results.mean(axis=2)
sigmas = masked_results.std(axis=2)
means.shape

# %%
for i in range(len(alpha_grid)):
    plt.errorbar(np.array(M_grid),means[:,i],sigmas[:,i],marker ='o',label = f"alpha = {alpha_grid[i]}")
plt.title(f"Bagging Normalized error: N_train = {N_train}, d= {d}, N_test= {N_test}")
plt.xlabel("M")
plt.xticks(M_grid)
plt.ylabel("normalized error")
plt.legend()
plt.show()

# %% [markdown]
# ## Store results

# %%
res_dict = {'N_train': N_train, 'N_test': N_test,'mgrid': M_grid, 'alpha_grid': alpha_grid, 'errors': converted_results.tolist()}

# %%
import json
import datetime
#with open(f'bagging_w_replacement_{str(datetime.date.today())}.json', 'w') as fp:
    #json.dump(res_dict, fp)
